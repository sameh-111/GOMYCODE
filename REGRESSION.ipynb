# %%
import pandas as pd
df = pd.read_csv("kc_house_data.csv")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
list(df.columns)
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
df.isnull().isnull()
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21608  False  False  False     False      False        False     False
# 21609  False  False  False     False      False        False     False
# 21610  False  False  False     False      False        False     False
# 21611  False  False  False     False      False        False     False
# 21612  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
del df["id"]

# %%
del df["date"]

# %%
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661  0.256794
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703  0.175429
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740  0.500653
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826  0.353949
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000 -0.005201
# floors         0.256794  0.175429   0.500653     0.353949 -0.005201  1.000000
# waterfront     0.266369 -0.006582   0.063744     0.103818  0.021604  0.023698
# view           0.397293  0.079532   0.187737     0.284611  0.074710  0.029444
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958 -0.263768
# grade          0.667434  0.356967   0.664983     0.762704  0.113621  0.458183
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512  0.523885
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize = (20,10))
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # most important features and their meanings:
#
# bedrooms: Number of Bedrooms/House
# bathrooms: Number of bathrooms/bedrooms
# sqft_living: square footage of the home
# sqft: square footage of the lot
# floors: Total floors (levels) in house
# waterfront: House which has a view to a waterfront
# grade: overall grade given to the housing unit, based on King County grading system. 1 poor ,13 excellent
# sqft_above: square footage of house apart from basement
# qft_living15: Living room area in 2015(implies-- some renovations) This might or might not have affected the lotsize area
# sqft_lot15: lotSize area in 2015(implies-- some renovations)

# %% [markdown]
# # Split the dataset into a training set and a testing set.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


x = df["sqft_lot15"].values.reshape(-1,1)
y = df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 30)

# %% [markdown]
# #linear regression

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)

predicted = reg.predict(x_test)

plt.scatter(x,y)
plt.xlabel("sqft lot15")
plt.ylabel("price")
plt.plot(x_test, predicted)
plt.show()
print("MSE", mean_squared_error(y_test, predicted))
print("R squared", r2_score(y_test, predicted))
# Out:
# MSE 134916048899.48882
# R squared 0.00740339790918032

# %%
print("coeff a = ", reg.coef_)
# Out:
# coeff a =  [1.0408173]

# %%
print("coeff b = ", reg.intercept_)
# Out:
# coeff b =  527312.0738872527

# %%
x = df["sqft_living"].values.reshape(-1,1)
y = df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 30)

reg = LinearRegression()
reg.fit(x_train, y_train)

predicted = reg.predict(x_test)

plt.scatter(x,y)
plt.xlabel("sqft living")
plt.ylabel("price")
plt.plot(x_test, predicted)
plt.show()
print("MSE", mean_squared_error(y_test, predicted))
print("R squared", r2_score(y_test, predicted))
# Out:
# MSE 64179676631.68388
# R squared 0.4879814110728805

# %%
print(" linear regression function : ", reg.coef_, "x  ", reg.intercept_)
# Out:
#  linear regression function :  [282.53959684] x   -46813.81594243983

# %%
x = df["grade"].values.reshape(-1,1)
y = df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 30)

reg = LinearRegression()
reg.fit(x_train, y_train)

predicted = reg.predict(x_test)

plt.scatter(x,y)
plt.xlabel("grade")
plt.ylabel("price")
plt.plot(x_test, predicted)
plt.show()
print("MSE", mean_squared_error(y_test, predicted))
print("R squared", r2_score(y_test, predicted))
# Out:
# MSE 66520040908.336136
# R squared 0.46931023543913863

# %%
#multi linear regression

# %%
x = df[["sqft_living","floors"]].values
y = df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

reg = LinearRegression()
reg.fit(x_train, y_train)

predicted = reg.predict(x_test)
print("MSE", mean_squared_error(y_test, predicted))
print("R squared", r2_score(y_test, predicted))
# Out:
# MSE 61951091318.60023
# R squared 0.47907107872096866

# %%
x = df[["bathrooms","grade"]].values
y = df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 0)

reg = LinearRegression()
reg.fit(x_train, y_train)

predicted = reg.predict(x_test)
print("MSE", mean_squared_error(y_test, predicted))
print("R squared", r2_score(y_test, predicted))
# Out:
# MSE 61626427207.54167
# R squared 0.4818010859178067

# %%
x = df[["sqft_living","floors", "grade"]].values
y = df["price"].values

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 30)

reg = LinearRegression()
reg.fit(x_train, y_train)

predicted = reg.predict(x_test)

print("MSE", mean_squared_error(y_test, predicted))
print("R squared", r2_score(y_test, predicted))
# Out:
# MSE 56997599139.88252
# R squared 0.5452792563708722

# %% [markdown]
# #polynomial regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score

# %%
x = df[["grade","bathrooms"]].values
y = df.price.values

# %%
x.shape
# Out:
# (21613, 2)

# %%
y.shape
# Out:
# (21613,)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state= 0)

# %%
poly= PolynomialFeatures(degree = 3)
x_train_fit = poly.fit_transform(x_train)

# %%
reg= LinearRegression()
reg.fit(x_train_fit, y_train)
# Out:
# LinearRegression()

# %%
x_test_fit = poly.fit_transform(x_test)
predicted_test = reg.predict(x_test_fit)

# %%
print("MSE : ", mean_squared_error(y_test, predicted_test))
# Out:
# MSE :  50995294675.69666

# %%
print("R2 : ", r2_score(y_test, predicted_test))
# Out:
# R2 :  0.5711952238403728
